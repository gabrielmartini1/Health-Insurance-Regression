# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielmartini1/Health_Insurance_AutoML_Regression/blob/main/Heath_Insurance_AutoML.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ---
#
# ## **Previsão de Custos de Seguro Saúde com AutoML**
#
# ---
# <p>by Gabriel Martini - Data Scientist</p>
# <p>April 25, 2023</p>
#
# <p align="right"><font size="1.5">Imagem de Iuri Imotov no <a href="https://br.freepik.com/vetores-gratis/conceito-de-servicos-de-seguros-esfera-3d-abstrata-ou-globo-com-icones-na-mao_9175929.htm#page=6&query=Health%20Insurance&position=30&from_view=search&track=robertav1_2_sidr">Freepik</a></p></font>
#
# <img alt="Health Insurance" width="100%" src="https://img.freepik.com/vetores-gratis/conceito-de-servicos-de-seguros-esfera-3d-abstrata-ou-globo-com-icones-na-mao_127544-1099.jpg?size=626&ext=jpg&ga=GA1.1.2136607038.1682451857&semt=robertav1_2_sidr">

# %% [markdown]
# <br>
#
# ##**1. Introdução**
#
# <p align="justify">O seguro saúde é um tema de grande relevância no cenário nacional e internacional, visto que a saúde é um bem fundamental para o bem-estar e a qualidade de vida das pessoas. No Brasil, a questão do seguro saúde é especialmente relevante, uma vez que o Sistema Único de Saúde (SUS) não consegue atender a todas as demandas da população, deixando muitos cidadãos dependentes de serviços privados de saúde.</p>
#
# <p align="justify">A questão da cobertura do seguro saúde é uma grande preocupação em todo o mundo, pois muitas pessoas enfrentam dificuldades para obter acesso a serviços de saúde de qualidade e acessíveis financeiramente. Em muitos países, a questão do seguro saúde é agravada pela falta de regulamentação adequada, o que pode levar a abusos por parte de seguradoras e prestadores de serviços de saúde.</p>
#
# <p align="justify">Além disso, outro problema enfrentado em muitos países é a dificuldade de acesso a tratamentos de alta complexidade e a medicamentos de alto custo, o que pode levar a um desequilíbrio financeiro para as famílias e até mesmo à falência de empresas de seguros saúde.</p>
#
# <p align="justify">No Brasil, a questão do seguro saúde é agravada pela desigualdade social e pela falta de acesso a serviços de saúde de qualidade em muitas regiões do país. Além disso, há ainda uma série de problemas relacionados à regulação do setor de seguros saúde, incluindo a falta de transparência na definição dos preços e na cobertura dos serviços, o que pode gerar prejuízos para os consumidores.</p>
#
# <p align="justify">Diante desse cenário, é fundamental que haja uma discussão ampla e aprofundada sobre o tema do seguro saúde, buscando soluções que permitam um acesso justo e equitativo a serviços de saúde de qualidade, tanto no Brasil quanto no mundo.</p>
#
# <p align="justify">O seguro saúde é uma modalidade em que há intermediação financeira de uma entidade seguradora que cobre ou reembolsa gastos com assistência médica, ao prestador ou ao segurado, segundo as condições estabelecidas em contrato</p>
#
# <p align="justify">A empresa responsável pela comercialização e operacionalização deste tipo de assistência à saúde é uma corretora de seguros. Portanto, ele funciona como qualquer outro tipo de seguro: o usuário faz o pagamento de um prêmio mensal e aciona a seguradora sempre que precisa utilizar um serviço incluso no plano contratado.</p>
#
# <p align="justify">Um grande diferencial desse modelo para o usuário é a possibilidade de escolher o profissional, a clínica, hospital onde quer realizar seu atendimento médico.</p>
#
# <p align="justify">No Brasil, assim como os planos de saúde, o Seguro Saúde é supervisionado pela Agência Nacional de Saúde Suplementar (ANS), que é responsável pela regulamentação e fiscalização dos seguros de saúde.</p>
#
# <p align="justify">Anteriormente, os seguros eram monitorados pela Superintendência de Seguros Privados (SUSEP), porém, a Lei 10.185 transferiu para a ANS a obrigação de regulamentar todas as operadoras de seguro, especializadas no setor.</p>
#
# <p align="justify">A Lei nº 9.656, conhecida como a Lei dos Planos de Saúde, estabelece as regras e condições mínimas que os planos e seguros privados de assistência à saúde devem oferecer aos seus usuários, bem como as regras para a contratação, rescisão e renovação desses planos, o cálculo dos reajustes dos preços, entre outras disposições. Essa lei tem como objetivo principal proteger os direitos dos consumidores que utilizam serviços de saúde privados no país.</p>
#
# <p align="justify">As principais modalidades do seguro saúde são: seguro saúde hospitalar, seguro saúde com obstetrícia, seguro saúde ambulatorial e o seguro saúde hospitalar + ambulatorial.</p>
#
# <p align="justify">O seguro hospitalar é a modalidade que garante internações em ambiente hospitalar, com um determinado número de diárias prevista em contrato.</p>
#
# <p align="justify">O seguro saúde hospitar com obstetrícia funciona como o seguro saíude hospitalar, porém inclui procedimentos e exames relacionados à gravidez, como pré-natal e assistência ao parto.</p>
#
# <p align="justify">Seguro saúde ambulatorial é a cobertura de assistência médica em consultórios, ambulatórios e clínicas, além do atendimento de emergência. Essa modalidade permite a realização de examoes de imagem e outros procedimentos importantes, porém sem o uso da internação</>
#
# <p align="justify">Seguro saúde hospitalar + ambulatorial é a modalidade que garante acesso às consultas, procedimentos, exames e internações.</p>
#
# <p align="justify">A Organização Mundial da Saúde (OMS) apresentou um estudo técnico sobre as constribuições da Inteligência Artificial (IA) e o aprendizado de máquina (Machine Learning) para a área da saúde.</p>
#
# <p align="justify">O documento técnico aborda temas como a previsão de gastos, gestão de riscos, detecção de fraudes e evidencia o potencial da precisão de análise de dados em comparação aos métodos estatísticos tradicionais.</p>
#
# <p align="justify">O documento técnico define IA como o desempenho por programas de computador de tarefas comumente associadas a seres inteligentes e Machine Learning como um tipo de IA que se baseia no uso de técnicas de modelagem estatística e matemática para definir e analisar dados.</p>
#
# <p align="justify">Na área de previsão de gastos com saúde, os estudos indicam que a utilização de Machine Learning pode tornar a alocação de recursos mais eficiente e equitativa, além de possibilitar o aprimoramento do ajuste de risco e o gerenciamento da população, com o intuito de atender às necessidades de grupos específicos. Contudo, se não forem bem utilizadas, essas informações traduzidas pelo ML podem causar o efeito oposto: exclusão de grupos mais necessitados e aumento de suas contribuições para as operadoras.</p>
#
# <p align="justify">Sobre pontuação de risco, as tecnologias podem ter potencial para estimular a promoção da saúde entre as pessoas. Já existem diversas operadoras de planos de saúde que aplicam ML a diferentes dados recebidos por seus parceiros de negócios, desde academias, uso de serviços de saúde e até compras em supermercados, com o intuito de analisar e mensurar o comportamento saudável dos clientes.</p>
#
# <p align="justify">Sobre a gestão de sinistros e detecção de fraudes, o estudo indicou que o uso de Machine Learning e da IA trouxeram muitos benefícios, com o aumento da precisão sobre a classificação de sinistros legítimos e fraudulentos. Entretanto, o estudo prevê a necessidade de novas pesquisas para se conhecer os possíveis riscos e desafios das tecnologias para o segmento da saúde.</p>
#
# <p align="justify">Em 2019, o Ministério da Saúde, através do seu Mapa Estratégico, apresentou o Plano Nacional de Saúde 2020/2023. Dentre as vertentes desse plano, observa-se a necessidade da instituição em desenvolver a gestão da informação e do conhecimento, bem como, ampliar o conhecimento científico e a oferta de soluções tecnológicas em saúde.</p><br>
#
#
# <center><img alt="Health Insurance" width="60%" src="https://raw.githubusercontent.com/gabrielmartini1/Health_Insurance_AutoML_Regression/main/img/ms_mapa.png"></center><br>
#
# <p align="justify">AutoML, ou Machine Learning automático, é uma técnica que visa automatizar todo o processo de criação de modelos de Machine Learning. Isso inclui desde a seleção de algorítmos e configuração de hiperparâmetros até a preparação dos dados e avaliação do desempenho do modelo.</p>
#
# <p align="justify">Uma das principais vantagens do AutoML é a redução do tempo e esforço necessários para criar modelos de Machine Learning. Isso ocorre porque a maior parte do processo é automatizada, permitindo que os usuários criem modelos com apenas alguns cliques. Além disso, o AutoML é capaz de lidar com tarefas como pré-processamento de dados, seleção de recursos e ajuste de hiperparâmetros, o que pode ser bastante complexo e demorado para um especialista humano.</p>
#
# <p align="justify">Outra vantagem do AutoML é a sua capacidade de criar modelos de alta qualidade. Isso ocorre porque o AutoML utiliza técnicas avançadas de Machine Learning, como algorítmos genéticos e aprendizado por reforço, para encontrar a melhor combinação de algorítmos e hiperparâmetros.</p>
#
# No entanto, é importante notar que o AutoML não é uma solução perfeita para todos os casos de uso de Machine Learning. Em algumas situações, um especialista humano pode ser capaz de obter melhores resultados, especialmente se o conjunto de dados é muito específico ou se a tarefa de Machine Learning é muito complexa. Além disso, o AutoML pode ser limitado por restrições de tempo ou orçamento, o que pode afetar a qualidade do modelo gerado.</p>
#
# ###**1.1 Objetivos Gerais**
#
# * Analisar a previsão de custos do seguro saúde, através do Pandas Profiling;
#
# * Investigar o impacto da previsão de custos de seguro saúde, levando em consideração a idade, sexo do segurado, IMC, número de dependentes e fumantes e não fumantes;
#
# * Desenvolver uma solução de Machine Learning eficiente com o modelo de Regressão, utilizando a biblioteca de Pycaret do Python.

# %% [markdown]
# ## **2. Obtenção dos Dados**
#
# ### **2.1 Contextualização**
#
# <p align="justify">A previsão de custos de seguro saúde é uma das áreas em que as empresas podem obter grandes benefícios com a adoção do Machine Learning. Isso ocorre porque a previsão de custos é uma tarefa complexa, que envolve a análise de uma grande quantidade de dados e a identificação de padrões que possam ajudar a prever os custos futuros.</p>
#
# <p align="justify">Com o uso de técnicas de Machine Learning, as empresas podem economizar custos significativos na previsão de custos de seguro saúde. O Machine Learning é capaz de analisar grandes conjuntos de dados e identificar padrões complexos. Com o Machine Learning, muitas das tarefas repetitivas e demoradas podem ser automatizadas, permitindo que os especialistas se concentrem em tarefas mais complexas e de alto valor agregado.</p>
#
# <p align="justify">Outra forma em que o Machine Learning pode ajudar as empresas a economizar custos é por meio da detecção precoce de fraudes em seguros de saúde. O Machine Learning pode ser usado para identificar padrões de comportamento suspeitos nos dados, permitindo que as empresas detectem fraudes em um estágio inicial e reduzam os custos associados a essas fraudes.</p>
#
# ### **2.2 Importação dos dados**
#
# <p align="justify">O conjunto de dados deste projeto ("insurance.csv"), encontra-se na plataforma do site Kaggle.com,  e está disponível para consulta pública e download no endereço (https://www.kaggle.com/datasets/annetxu/health-insurance-cost-prediction?resource=download).</p>
#
# <p align="justify">"Kaggle" é uma plataforma online que hospeda competições de ciência de dados, onde empresas e pesquisadores podem postar seus conjuntos de dados e desafiar a comunidade global de cientistas de dados a encontrar soluções para problemas complexos.</p>

# %%
# Bibliotecas para o projeto Health Insurance com Modelo de Regressão
import pandas as pd
import numpy as np

# Ferramenta útil para a visualização de dados em Python. O pacote "pyplot" é uma subbiblioteca do "matplotlib" 
import matplotlib.pyplot as plt

# Biblioteca de visualização de dados para Python, que é construída em cima do Matplotlib
import seaborn as sns

# Função usada para configurar o estilo do Seaborn
sns.set_style('dark') # outras opções ('white', 'whitegrid', 'darkgrid', 'ticks')

# Instalar a biblioteca para gerar relatório de perfil
# !pip install pandas_profiling --upgrade
from pandas_profiling import ProfileReport

# Instalar a biblioteca de aprendizado de máquina automatizado (AutoML) 
# !pip install pycaret -U

# Importar todas as funções e classes do módulo regression
from pycaret.regression import *

# %%
# Carregar o dataset 'insurance.csv' (by Kaggle.com)
df = pd.read_csv("https://raw.githubusercontent.com/gabrielmartini1/Health_Insurance_AutoML_Regression/main/data/insurance.csv")

# %% [markdown]
# <p align="justify">Com os dados já importados para o DataFrame, vamos agora realizar a análise exploratória dos dados, antes de construirmos um modelo automático de Machine Learning.</p>

# %% [markdown]
# ## **3. Análise Exploratória**
#
# <p align="justify">A etapa de análise exploratória de dados é uma fase muito importante dentro do escopo do projeto. Através de diversas técnicas para examinar e entender a estrutura dos dados, podemos identificar problemas e anomalias, e obter insights preliminares que podem orientar a seleção de variáveis, modelos e hipóteses a serem testadas.</p>
# <br>
#
# ###**3.1 Dicionário das variáveis**
#
# * `age` - idade do segurado
# * `sex` - sexo do segurado
# * `bmi` - índice de massa corporal (IMC) do segurado
# * `children` - número de dependentes do segurado
# * `smoker` - se o segurado é fumante ou não
# * `region` - região em que o segurado vive
# * `charges` - custo médico anual cobrado pelo plano de saúde

# %% [markdown]
# ###**3.2 Visão Geral do dataset**
#
#
# <p align="justify">Uma primeira impressão sobre o dataset "insurance.csv", é visualizarmos o início das primeiras entradas de dados, conforme o código e output abaixo:</p>

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# <p align="justify">Para realizarmos a análise exploratória dos dados neste dataset, faremos uso da ferramenta "Pandas Profiling", que é uma biblioteca em Python que oferece uma maneira ágil e fácil de entender a distribuição e a qualidade dos dados em um conjunto de dados.</p>
#
# <p align="justify">O Pandas Profiling automatiza muitas das tarefas de análise exploratória de dados. Ele gera relatórios detalhados e visualmente atraentes com informações sobre as vairáveis de um dataset, incluindo estatísticas resumidas, distribuições, quartis, correlações, detecção de valores ausentes e outliers nos dados.</p>

# %%
# Criar um relatório de perfil para o conjunto de dados
report = ProfileReport(df)

# Criar a visualização iframe
report.to_notebook_iframe()
print("")
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# <iframe width="100%" height="800px" srcdoc="&lt;!doctype html&gt;&lt;html lang=en&gt;&lt;head&gt;&lt;meta charset=utf-8&gt;&lt;meta name=viewport content=&quot;width=device-width, initial-scale=1, shrink-to-fit=no&quot;&gt;&lt;meta name=description content=&quot;Profile report generated by YData! Visit us at https://ydata.ai&quot;&gt;&lt;meta name=author content=&quot;YData and the open source community.&quot;&gt;&lt;meta name=generator content=&quot;Pandas Profiling v3.6.6&quot;&gt;&lt;meta name=url content=https://github.com/ydataai/pandas-profiling&gt;&lt;meta name=date content=&quot;2023-04-29 13:17:02.601668&quot;&gt;&lt;title&gt;Pandas Profiling Report&lt;/title&gt;&lt;style&gt;
# /*!
#  * Bootstrap v3.3.7 (http://getbootstrap.com)
#  * Copyright 2011-2016 Twitter, Inc.
#  * Licensed under MIT (https://github.com/twbs/bootstrap/blob/master/LICENSE)
# ...

# %% [markdown]
# <p align="justify">O relatório de perfil gerado pelo Pandas Profiling, nos apresentou uma visão geral dos principais indicadores da análise de dados do dataset "insurance.csv".</p>

# %% [markdown]
# ###**3.3 Tamanho do dataset**
#
# <p align="justify">Através do relatório de perfil conseguimos levantar rapidamente o tamanho do conjunto de dados, que contém 1.338 registros e 7 colunas, sendo 6 variáveis de entrada e 1 variável de saída ("Charges").</p>

# %% [markdown]
# ###**3.4 Conhecendo os tipos das variáveis**
#
# <p align="justify">O dataset possui 7 variáveis, sendo 'age' e 'children', númericas do tipo (int), 'bmi' e 'charges', numéricas do tipo (float), 'sex' e 'region' categóricas do tipo (object) e 'smoker' que é do tipo (variável booleana).</p>

# %% [markdown]
# ###**3.5 Porcentagem de valores ausentes das colunas**
#
# <p align="justify">Em consulta ao relatório de perfil, podemos confirmar que não constam valores ausentes (missing value) para as variáveis do conjunto de dados.</p>

# %% [markdown]
# ###**3.6 Porcentagem de valores duplicados (duplicate rows)**
#
# <p align="justify">Segundo o relatório, consta apenas 1 registro duplicado no dataset, o qual deverá ser excluído para não influenciar no levantamento estatístico, conforme apresentado abaixo:</p>

# %%
# Identificar as linhas duplicadas
duplicatas = df.duplicated()

# Imprimir as linhas duplicadas
print(df[duplicatas])
# Out:
#      age   sex    bmi  children smoker     region    charges
# 581   19  male  30.59         0     no  northwest  1639.5631

# %%
# Excluir valores duplicados
df.drop_duplicates(inplace=True)

# %%
# Verificar a existência de valores duplicados no dataset
vd = df.duplicated().sum()
print("Valores Duplicados: ", vd)
# Out:
# Valores Duplicados:  0

# %% [markdown]
# ###**3.7 Porcentagem de valores igual a zero**
#
# <p align="justify">Geralmente, uma alta porcentagem de valores ausentes pode indicar problemas na coleta de dados ou um viés nos dados. No entanto, no caso deste dataset, a única coluna com 574 registros (42,9%) iguais a zero é a variável 'children', que não apresenta um problema na coleta de dados. Na verdade, o valor zero nessa coluna indica que, dentre os 1.337 clientes do dataset, 573 responderam que não possuem filhos. Portanto, a presença desses valores não deve ser tratada como dados ausentes ou incorretos, mas sim considerada como uma opção válida de resposta para a variável 'children'.</p>

# %%
count_children = df['children'].value_counts().sort_index()
print("Contagem de valores únicos em children:\n", count_children)
# Out:
# Contagem de valores únicos em children:
#  0    573
# 1    324
# 2    240
# 3    157
# 4     25
# 5     18
# Name: children, dtype: int64

# %% [markdown]
# ###**3.8 Correlação entre as variáveis**
#
# <p align="justify">Pela análise do relatório, as conclusões sobre as correlações entre as variáveis foram:
#
# * <p align="justify">Age: Tem uma correlação positiva moderada com "charges" (0,534), o que sugere que pessoas mais velhas tendem a pagar mais por seguros de saúde.</p>
#
# * <p align="justify">BMI: Tem uma correlação positiva fraca com "charges" (0,119), o que sugere que pessoas com índices de massa corporal mais altos tendem a pagar um pouco mais por seguros de saúde. Também tem uma correlação moderada com "region" (0,164).</p>
#
# * <p align="justify">Children: Tem uma correlação positiva fraca com "charges" (0,133), o que sugere que pessoas com mais filhos tendem a pagar um pouco mais por seguros de saúde. Também tem uma correlação positiva fraca com "smoker" (0,038).</p>
#
# * <p align="justify">Charges: Tem uma forte correlação positiva com "smoker" (0,832), o que sugere que fumantes tendem a pagar muito mais por seguros de saúde do que não fumantes. Também tem uma correlação moderada com "age" (0,534) e uma correlação positiva fraca com "bmi" (0,119) e "children" (0,133).</p>
#
# * <p align="justify">Sex: Não tem uma correlação significativa com as outras variáveis.</p>
#
# * <p align="justify">Smoker: Tem uma forte correlação positiva com "charges" (0,832), o que sugere que fumantes tendem a pagar muito mais por seguros de saúde do que não fumantes. Também tem uma correlação positiva fraca com "children" (0,038) e "age" (0,043).</p>
#
# * <p align="justify">Region: Tem uma correlação positiva moderada com "bmi" (0,164) e uma correlação positiva fraca com "charges" (0,065). Não tem uma correlação significativa com as outras variáveis.</p>

# %% [markdown]
# ###**3.9 Padrão de Distribuição da variável 'Charges'**
#
# <p align="justify">A partir dos dados da variável 'charges', vamos traçar um histograma para mostrar a distribuição dos custos de seguro saúde em termos de frequência.</p>

# %%
# Plotar histograma da variável 'charges'
histogram = sns.distplot(df['charges'], hist_kws={'color':'#3274a0', 'edgecolor':'black'}, kde_kws={'color':'blue'})
histogram.set_xlabel('Custos de seguro saúde')
histogram.set_ylabel('Frequência')
histogram.set_title('Padrão de Distribuição de Custos de Seguro Saúde');

# %% [markdown]
# <p align="justify">Podemos ver que a maioria dos custos de seguro saúde está concentrada na faixa de 0 a 20.000 dólares, mas há alguns valores extremamente altos que se destacam, superando a faixa de 60.000 dólares. Isso sugere que algumas pessoas têm custos de seguro saúde muito elevados, enquanto a maioria tem custos mais baixos. É importante observar que o padrão de distribuição dos custos de seguro saúde é assimétrico e tem uma cauda longa à direita, o que significa que há um número relativamente pequeno de pessoas com custos extremamente altos.</p>
#
# <p align="justify">Sabendo que existe faixa de custo de seguro saúde acima de 60.000 dólares, vamos levantar os 10 maiores custos e verificar quais variáveis estão influenciando diretamente o resultado.</p>

# %%
# Verificar os 10 maiores valores da coluna 'charges'
top_5_charges = df.nlargest(10, 'charges')

# analisar as informações dos 10 maiores custos
print(top_5_charges, "\n")
# Out:
#       age     sex     bmi  children smoker     region      charges
# 543    54  female  47.410         0    yes  southeast  63770.42801
# 1300   45    male  30.360         0    yes  southeast  62592.87309
# 1230   52    male  34.485         3    yes  northwest  60021.39897
# 577    31  female  38.095         1    yes  northeast  58571.07448
# 819    33  female  35.530         0    yes  northwest  55135.40209
# 1146   60    male  32.800         0    yes  southwest  52590.82939
# 34     28    male  36.400         1    yes  southwest  51194.55914
# 1241   64    male  36.960         2    yes  southeast  49577.66240
# 1062   59    male  41.140         1    yes  southeast  48970.24760
# 488    44  female  38.060         0    yes  southeast  48885.13561

# %% [markdown]
# <p align="justify">Analisando o output acima, podemos confirmar que as varáveis 'smoker' (fumantes) e 'age' (idade) são os principais atributos responsáveis pelo alto custo do seguro saúde.</p>

# %% [markdown]
# ###**3.10 Análise gráfica das relações existentes entre as variáveis**
#
#
# <p align="justify">Com base no gráfico de pares, podemos observar que há uma forte correlação positiva entre as variáveis 'charges' e 'age', o que indica que o custo do seguro saúde tende a aumentar com a idade.</p>
#
# <p align="justify">Também há uma correlação positiva moderada entre as variáveis 'charges' e 'bmi', o que indica que pessoas com IMC mais alto tender a ter custos de seguro mais altos.</p>
#
# <p align="justify">A variável 'children' apresentou uma fraca correlação com as demais variáveis. Já a variável 'region' não apresentou ter nenhuma correlação com as demais variáveis. Provavelmente, pelo fato de que é uma variável categórica e não numérica.</p>

# %%
#Plotar um gráfico de pares para verificar a relação existente entre as variáveis
sns.pairplot(df);

# %% [markdown]
# ## **4. Divisão dos dados (data splitting)**
#
# <p align="justify">Data splitting, também conhecido como divisão de dados, é uma técnica usada em machine learning para dividir o conjunto de dados disponível em conjuntos de treinamento e teste. O conjunto de treinamento é usado para treinar o modelo de machine learning, enquanto o conjunto de teste é usado para avaliar a capacidade de generalização do modelo para novos dados não vistos durante o treinamento.</p>
#
# <p align="justify">A técnica de divisão de dados é fundamental em machine learning para evitar o overfitting, que ocorre quando o modelo é treinado em excesso com o conjunto de treinamento e perde a capacidade de generalização para novos dados. A divisão dos dados permite que o modelo seja treinado em um conjunto de dados independente do conjunto de teste, o que ajuda a avaliar a capacidade de generalização do modelo.</p>
#
# <p align="justify">Os conjuntos de treinamento e teste são geralmente divididos em proporções comuns, como 70-30, 80-20 ou 90-10, em que a maioria dos dados é usada para treinar o modelo (conjunto de treinamento) e uma pequena parcela é usada para testar a capacidade de generalização do modelo (conjunto de teste). É importante garantir que a divisão dos dados seja feita de forma aleatória e estratificada, para garantir que as classes ou distribuições de características do conjunto de dados sejam mantidas em ambas as partições.</p>

# %%
# Separando os dados em teste e treino
test = df.sample(frac=0.10)
train = df.drop(test.index)

test.reset_index(inplace=True, drop=True)
train.reset_index(inplace=True, drop=True)

# %% [markdown]
# <p align="justify">Conforme o código apresentado acima, já efetuamos a separação dos dados em teste e treino, aplicando uma amostra aleatória fracionada em 10% para o conjunto de teste.</p>

# %%
# Verificando o formato dos conjuntos
print(train.shape)
print(test.shape)
# Out:
# (1203, 7)
# (134, 7)

# %% [markdown]
# <p align="justify">Através do comando "shape( )", podemos  verificar a integridade e tamanho dos conjuntos de treino e teste. Observa-se, que o conjunto de treino do DataFrame apresenta 1.203 linhas e 7 colunas, enquanto que o conjunto de teste apresenta 134 linhas e 7 colunas.</p>

# %% [markdown]
# ## **5. Criando o ambiente de modelagem no PyCaret**
#
# <p align="justify">A criação de um ambiente de modelagem no PyCaret é importante por várias razões. Em primeiro lugar, o PyCaret é uma biblioteca de machine learning de alto nível que permite o desenvolvimento e a avalição de modelos de machine learning rapidamente, sem ter que escrever muito código. No entanto, para aproveitar ao máximo o PyCaret, é necessário criarmos um ambiente de modelagem adequado usando a função setup().</p>
#
# <p align="justify">Ao criarmos um ambiente de modelagem no PyCaret, garantimos que os dados sejam pré-processados adequadamente para modelagem, que as variáveis independentes e dependentes estejam corretamente definidas, que a divisão de dados seja feita de forma aleatória e estratificada e que o ambiente de modelagem seja configurado corretamente com as bibliotecas e dependências necessárias.</p>
#
# <p align="justify">Além disso, ao criarmos um ambiente de modelagem no PyCaret, podemos simplificar muitas das longas tarefas associadas ao pré-processamento de dados, como o tratamento de valores ausentes, a codificação de variáveis categóricas e normalização de dados. Essas transformações são aplicadas automaticamente pela função setup( ) e podem ser ajustadas facilmente usando os parâmetros da função.</p>
#
# ### **5.1 Criando múltiplas tarefas com a Função Setup**
#
# <p align="justify">Como já sabemos, a criação do ambiente de modelagem no PyCaret é realizada através da função "setup( )", a qual realiza várias tarefas importantes para preparar os dados para a modelagem, incluindo:</p>
#
# * <p align="justify">Carregar os dados: a função "setup( )" carrega o conjunto de dados no ambiente PyCaret para que possa ser usado em análises e modelagem de machine learning.</p>
#
# * <p align="justify">Definir a variável target: precisamos especificar qual coluna do conjunto de dados é a variável target para o modelo de Machine Learning.</p>
#
# * <p align="justify">Selecionar as variáveis independentes: precisamos especificar quais colunas do conjunto de dados são as variáveis independentes. Essas são as variáveis que o modelo usará para prever a variável target.</p>
#
# * <p align="justify">Pré-processar os dados: a função setup( ) aplica automaticamente várias transformações de pré-processamento de dados, incluindo tratamento de valores ausentes, codificação de variáveis categóricas, normalização de dados e outras técnicas de pré-processamento. Essas transformações ajudam a garantir que os dados estejam em um formato adequado para a modelagem.</p>
#
# Dividir os dados: a função setup( ) divide automaticamente o conjunto de dados em conjuntos de treinamento e teste usando a técnica de divisão holdout.
#
# * <p align="justify">Configurar o ambiente: a função setup( ) configura automaticamente o ambiente PyCaret com as bibliotecas e dependências necessárias para a modelagem de machine learning.</p>
#
# * <p align="justify">O resultado da função setup( ) é um objeto que contém as informações sobre as transformações de pré-processamento aplicadas aos dados, bem como os conjuntos de treinamento e teste, que são usados na etapa de treinamento do modelo. Com isso, podemos passar esse objeto para as funções de modelagem do PyCaret para avaliarmos diferentes modelos de machine learning.</p>

# %%
# Configurando o ambiente de modelagem
reg = setup(data = train, target = 'charges', session_id=1)
# Out:
# <style type="text/css">
# #T_c48f1_row10_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_c48f1" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_c48f1_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_c48f1_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c48f1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c48f1_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_c48f1_row0_col1" class="data row0 col1" >1</td>
#     </tr>
#     <tr>
#       <th id="T_c48f1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_c48f1_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_c48f1_row1_col1" class="data row1 col1" >charges</td>
#     </tr>
#     <tr>
#       <th id="T_c48f1_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %% [markdown]
# <p align="justify">Quando o código da função "setup( )" é executado corretamente, o ambiente do PyCaret imprime um grid com várias informações importantes sobre o pipeline de pré-processamento.</p>
#
# <p align="justify">Ao defirnirmos o parâmetro "session_id=1" na função "setup( )", estamos garantindo que o processamento dos dados e a construção do modelo serão executados de forma determinítica, ou seja, com a mesma aleatoriedade a cada execução do código.</p>
#
# <p align="justify">O valor que é definido para o parâmetro "session_id=1", estabelece uma semente ("seeding") para a aleatoriedade, o que garante que o processamento das linhas de código seja sempre realizado da mesma forma. Com isso, a reprodutibilidade do processo de modelagem é garantida, o que é importante para avaliarmos a performance do modelo de forma consistente e confiável.</p>

# %% [markdown]
# ###**5.1.1 Dicionário do ambiente de modelagem**
# <br>
#
# | Parâmetros            | Descrição                                             |
# |-----------------------------  |----------------------------------------------|
# | `Session id`                  | O valor atribuído à semente que garante a reprodutibilidade do processo de modelagem.                                    |
# | `Target`                      | O nome da variável que será usada como target na tarefa de regressão.                                                                     |
# | `Original data shape`.        | O número de linhas e colunas do conjunto de dados original.                                                                      |
# | `Transformed data shape`      | O número de linhas e colunas após a transformação dos dados realizada pela função setup( ).                                                                              |
# | `Transformed train set shape` | O número de linhas e colunas do conjunto de treino, após a divisão dos dados em conjuntos de treino e teste.               |
# | `Transformed test set shape`           | O número de linhas e colunas do conjunto de teste, após a divisão dos dados em conjuntos de treino e teste.    |
# | `Ordinal features`          | O número de variáveis ordinais no conjunto de dados.                                                                         |
# | `Numeric features`           | O número de variáveis numéricas no conjunto de dados.                                                                         |
# | `Categorical features`          | O número de variáveis categóricas no conjunto de dados.                                                             |
# | `Preprocess`             |  Indica se o pré-processamento dos dados foi realizado pela função setup().                                                 |
# | `Imputation type`     | O tipo de imputação (preenchimento de valores faltantes).                                                                    |
# | `Numeric imputation`            | O tipo de imputação (preenchimento de valores faltantes) realizado para as variáveis numéricas.                      |
# | `Categorical imputation`         | O tipo de imputação (preenchimento de valores faltantes) realizado para as variáveis categóricas.                    |
# | `Maximum one-hot encoding`      | O número máximo de categorias para realizar a codificação one-hot das variáveis categóricas.                               |
# | `Log Experiment`      |  Indica se o log da experimentação será feito.       |
# | `CPU Jobs`     | O número de núcleos de processamento usados para paralelizar a execução do código. O valor -1 indica que o número de núcleos será definido automaticamente.                                                               |
# | `Use GPU`     | Indica se a GPU será utilizada para acelerar o processamento.                                                                 |
# | `Experiment Name`     |  O nome da experimentação.                           |
# | `USI`     | Um identificador único da experimentação.                        |
# | `Fold Generator`     | O gerador de dobras usado na validação cruzada.       |
# | `Fold Number`     | O número de dobras usado na validação cruzada.           |

# %% [markdown]
# ## **6. Comparando os modelos**
#
# <p align="justify">Comparar modelos é uma etapa crucial no processo de construção de um modelo de aprendizado de máquina. Ao comparar diferentes modelos usando métricas de desempenho, podemos identificar qual funciona melhor para o conjunto de dados e tarefa de aprendizado de máquina.</p>
#
# <p align="justify">O PyCaret é uma biblioteca de aprendizado de máquina que oferece vários modelos pré-definidos para tarefas de classificação, regressão e clustering. Cada modelo tem suas próprias características e hiperparâmetros que podem afetar o desempenho do modelo em um conjunto de dados específico. Portanto, é importante comparar diferentes modelos para encontrar o melhor modelo para a tarefa em questão.</p>
#
# <p align="justify">Essa função treina todos os modelos na biblioteca do PyCaret e os avalia usando a validação cruzada, que é uma técnica utilizada para avaliar a performance de um modelo de aprendizado de máquina. Nesse caso, a função realiza 10 folds por padrão, o que significa que o conjunto de dados é dividido em 10 partes iguais e o modelo é treinado e avaliado 10 vezes, usando cada parte como conjunto de teste uma vez.</p>
#
# <p align="justify">A função imprime uma tabela que mostra a média dos valores de várias métricas de avaliação de modelos de aprendizado de máquina, incluindo MAE (Erro absoluto médio), MSE (Erro quadrático médio), RMSE (Raiz do erro quadrático médio), R2 (Coeficiente de determinação), RMSLE (Erro quadrático médio do logaritmo) e MAPE (Porcentagem absoluta média de erro).</p>

# %%
# Comparar modelos de ML
compare_models()
# Out:
# <style type="text/css">
# #T_41798 th {
#   text-align: left;
# }
# ...

# %% [markdown]
# <p align="justify">Após aplicarmos o comando "compare_models( )", podemos observar que foram gerados 19 modelos diferentes de Regressão, usando o PyCaret com 10 folds de validação cruzada e avaliados pelas 6 métricas de desempenho (MAE, MSE, RMSE, R2, RMSLE e MAPE).</p>
#
# <p align="justify">Ao analisarmos as métricas obtidas da tabela de avaliação dos modelos de aprendizado de máquina, é possível notarmos que o modelo Gradient Boosting Regressor (GBR) se destacou entre os demais, apresentando as melhores médias das métricas de avaliação. Portanto, o (GBR) será o modelo selecionado para seguir experimentando.</p>
#
# ### **6.1 Instanciando o Modelo**
#
# <p align="justify">A função "compare_models( )" não retorna modelos treinados, ela apenas avalia e compara o desempenho de vários modelos e retorna uma lista de objetos de modelo que podem ser treinados posteriormente com a função "create_model( )".</p>
#
# <p align="justify">A função "create_model" é usada para criar e avaliar os modelos selecionados, usando validação cruzada estratificada. Assim como o "compare_models", o output é uma tabela de pontuação que mostra MAE, MSE, RMSE, R2, RMSLE e MAPE por fold.</p>
#
# ### **6.1.1 Gradient Boosting Regressor (GBR)**
#
# <p align="justify">O Gradient Boosting é uma técnica muito poderosa para construir modelos preditivos e pode ser aplicado a uma variedade de problemas de aprendizado de máquina.</p>
#
# <p align="justify">O modelo funciona adicionando sequencialmente "Weak Learners" ao modelo, onde cada um desses modelos tenta corrigir os erros do modelo anterior. Essa abordagem permite que o modelo seja altamente adaptativo e capaz de lidar com problemas complexos de regressão e classificação.</p>
#
# <p align="justify">Além disso, o Gradient Boosting é conhecido por sua capacidade de lidar com dados de alta dimensão e não-lineares, além de ter um bom desempenho em conjunto de dados desbalanceados. A seguir, vamos usar a função "create_models" para gerar a tabela de pontuação com as métricas de desempenho, conforme código e output abaixo:</p>

# %%
# Criar modelo
gbr = create_model('gbr', fold=10)
# Out:
# <style type="text/css">
# #T_f27d7_row10_col0, #T_f27d7_row10_col1, #T_f27d7_row10_col2, #T_f27d7_row10_col3, #T_f27d7_row10_col4, #T_f27d7_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_f27d7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f27d7_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_f27d7_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_f27d7_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_f27d7_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_f27d7_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_f27d7_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %% [markdown]
# ### **6.1.2 Ajustando os hiperparâmetros do Gradient Boosting Regressor**
#
# <p align="justify">O comando "tune_model( )" da biblioteca PyCaret é usado para ajustar os hiperparâmetros de um modelo de aprendizado de máquina, a fim de melhorar seu desempenho. O ajuste dos hiperparâmetros pode levar a uma melhoria significativa no desempenho do modelo, permitindo que ele se adapte melhor aos dados.</p>
#
# <p align="justify">A função tune_model( ) usa a técnica de busca em grade para procurar a combinação ideal de hiperparâmetros para o modelo. A busca em grade é uma técnica de otimização que permite que os hiperparâmetros do modelo sejam ajustados de maneira sistemática e automatizada, testando várias combinações possíveis de hiperparâmetros.</p>
#
# <p align="justify">Ao chamarmos a função tune_model( ), precisamos fornecer o objeto de modelo treinado como entrada. Em seguida, a função irá treinar o modelo novamente usando a técnica de busca em grade para encontrar os melhores valores de hiperparâmetros.</p>
#
# <p align="justify">O tune_model( ) retorna um objeto de modelo treinado com os melhores hiperparâmetros encontrados durante a busca em grade. Esse modelo pode então ser usado para fazer previsões em novos dados, conforme código abaixo:</p>

# %%
# Tunando modelo
tuned_gbr = tune_model(gbr, optimize = 'MAE')
# Out:
# <style type="text/css">
# #T_d867a_row10_col0, #T_d867a_row10_col1, #T_d867a_row10_col2, #T_d867a_row10_col3, #T_d867a_row10_col4, #T_d867a_row10_col5 {
#   background: yellow;
# }
# </style>
# <table id="T_d867a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d867a_level0_col0" class="col_heading level0 col0" >MAE</th>
#       <th id="T_d867a_level0_col1" class="col_heading level0 col1" >MSE</th>
#       <th id="T_d867a_level0_col2" class="col_heading level0 col2" >RMSE</th>
#       <th id="T_d867a_level0_col3" class="col_heading level0 col3" >R2</th>
#       <th id="T_d867a_level0_col4" class="col_heading level0 col4" >RMSLE</th>
#       <th id="T_d867a_level0_col5" class="col_heading level0 col5" >MAPE</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
# ...

# %% [markdown]
# <p align="justify">O output acima, indica que a função tune_model( ) está ajustando os hiperparâmetros do modelo usando validação cruzada com 10 folds para cada uma das 10 combinações possíveis de hiperparâmetros, totalizando 100 ajustes no modelo.</p>
#
# <p align="justify">Também podemos observar que o modelo original foi melhor do que o modelo ajustado, portanto a função "tune_model( )" irá retornar o modelo original ao invés do modelo ajustado. Isso pode acontecer, porque a busca em grade não encontrou nenhuma combinação de hiperparâmetros que melhorasse significativamente o desempenho do modelo em relação ao original.</p>
#
# <p align="justify">É sempre muito importante avaliarmos cuidadosamente o desempenho do modelo ajustado em comparação com o modelo original, bem como interpretar os resultados da busca em grade com cuidado para entendermos como os hiperparâmetros afetam o desempenho do modelo.</p>
#
# <p align="justify">Portanto, o modelo que se apresenta melhor, considerando as métricas de desempenho médio, é o modelo original, ou seja, o Gradient Boosting Regressor sem ajuste de hiperparâmetros.</p>

# %% [markdown]
# ### **6.2. Plotando modelos**
#
# <p align="justify">A função "plot_model( )" é uma ferramenta útil para visualizar a performance do modelo de diferentes apectos. Ele permite a visualização de várias métricas de desempenho, como "Residual Plot", "Prediction Error", "Feature Importance", entre outros.</p>
#
# <p align="justify">Para usarmos a função plot_model( ), basta fornecermos o modelo treinado como entrada e especificar qual tipo de plot desejamos. Por exemplo, plot_model(tuned_gbr, plot='residuals') plota o gráfico residual do modelo de aumento de gradiente ajustado. É importante notar que os tipos de plot disponíveis podem variar dependendo do modelo específico.</p>

# %%
# Plotando o modelo
plot_model(gbr, plot = 'error')

# %% [markdown]
# <p align="justify">No gráfico acima, é possível observarmos como o erro do modelo diminui à medida que o número de iterações aumenta. O objetivo da sintonia de hiperparâmetros é justamente encontrar a combinação de parâmetros que resulte em um modelo com menor erro possível, e essa curva pode ser uma ferramenta útil para avaliar a eficácia dessa sintonia.</p>

# %%
# Verificando as features mais importantes
plot_model(gbr, plot='feature')

# %% [markdown]
# <p align="justify">O gráfico de "feature importance" mostra uma representação visual da relevância de cada feature no modelo. Cada feature é representada por uma barra vertical, cuja altura indica a importância relativa da feature no modelo. Quanto maior a barra, maior a importância da feature para o modelo.</p>
#
# <p align="justify">Essa informação pode ser útil para identificar quais variáveis têm maior impacto na previsão do modelo e quais podem ser menos importantes ou até mesmo redundantes. A partir dessas informações, é possível selecionar as features mais relevantes e descartar as menos relevantes, o que pode ajudar a simplificar o modelo e melhorar seu desempenho.</p>
#
# <p align="justify">Analisando o gráfico, podemos perceber que a feature que apresentou maior relevância, refere-se à variável "smoker". Isso sugere que a presença ou não de tabagismo pode ser um fator relevante para prever os custos médicos. Em seguida, temos as variáveis "bmi" e "age", porém com menor relevância da feature para o modelo.</p>

# %%
# Gráfico 'feature importance'
plot_model(gbr, plot='learning')

# %% [markdown]
# <p align="justify">O gráfico de linhas "learning" plota a curva de aprendizado do modelo de regressão de Gradient Boosting. Essa curva representa o desempenho do modelo em relação ao número de amostras de treinamento usadas, o que pode ajudar a identificar se o modelo está sofrendo de underfitting ou overfitting.</p>

# %%
# Gráfico 'cook`s distance plot' para pontos atípicos
plot_model(gbr, plot='cooks')

# %% [markdown]
# <p align="justify">O gráfico do tipo "Cook's Distance Plot", é uma ferramenta usada para detectar pontos atípicos em um modelo de regressão. Ele plota os valores de Cook's Distance, que medem a influência de cada ponto de dados nas previsões do modelo, em relação ao índice de cada ponto de dados. Um ponto com alto valor de Cook's Distance pode ser considerado um ponto atípico que exerce uma grande influência nas previsões do modelo. O gráfico permite que o usuário identifique esses pontos atípicos e potencialmente investigue a causa de sua influência no modelo.</p>

# %% [markdown]
# ### **6.3 Fazendo Previsões**
#
# <p align="justify">Antes de finalizarmos o modelo, é recomendável que façamos uma checagem final, fazendo previsões no conjunto de teste e revisando as métricas de avaliação.</p>
#
# <p align="justify">O código predict_model(gbr) é utilizado para fazer previsões no conjunto de teste usando o modelo treinado (gbr) e retornar um DataFrame com as previsões resultantes. Esse código é útil para avaliar como o modelo treinado está performando em novos dados que não foram usados para treinar o modelo.</p>

# %%
# Fazer previsões
predict_model(gbr);
# Out:
# <style type="text/css">
# </style>
# <table id="T_4c077" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4c077_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4c077_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4c077_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4c077_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4c077_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4c077_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4c077_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4c077_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4c077_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_4c077_row0_col1" class="data row0 col1" >2447.3201</td>
# ...

# %% [markdown]
# ### **6.4 Finalizando o Modelo**
#
# <p align="justify">Finalizar o modelo significa aplicar o treinamento do modelo em todo o conjunto de dados e salvar o modelo treinado em um objeto para uso posterior em previsões com novos dados. A função "finalize_model( )" realiza essa etapa final do processo de treinamento, ajustando o modelo no conjunto completo de dados e retornando um objeto que pode ser usado para fazer previsões em novos dados.</p>
#
# <p align="justify">Quando utilizamos a função "finalize_model( )" para finalizar o modelo, o conjunto de dados inteiro, incluindo a parte que foi separada anteriormente para teste, é usado para treinar novamente o modelo com todos os dados disponíveis. Por isso, é necessário ter cuidado ao utilizar o modelo finalizado para fazer previsões no conjunto de teste separado anteriormente, pois os resultados podem ser enganosos. Isso ocorre porque o modelo já viu esses dados antes e ajustou seus parâmetros para melhor se ajustar a eles, o que pode levar a resultados superestimados. Para avaliar a capacidade de generalização do modelo, é importante utilizar novos dados não vistos pelo modelo.</p>

# %%
# Finalizar modelo
final_gbr = finalize_model(gbr)

# %% [markdown]
# <p align="justify">A seguir, vamos usar o modelo finalizado "final_gbr" para fazer previsões no conjunto de teste separado anteriormente e comparar os resultados com os que foram obtidos anteriormente com o modelo original. Isso serve para ilustrar como o uso do conjunto de teste anteriormente visto pelo modelo pode levar a resultados enganosos e superestimados.</p>

# %%
# Analisando a mudança nos resultados
predict_model(final_gbr);
# Out:
# <style type="text/css">
# </style>
# <table id="T_3ace7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ace7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_3ace7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_3ace7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_3ace7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_3ace7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_3ace7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_3ace7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ace7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ace7_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_3ace7_row0_col1" class="data row0 col1" >1845.9882</td>
# ...

# %% [markdown]
# <p align="justify">A principal diferença que podemos observar é que as métricas de desempenho melhoraram após finalizar o modelo. Isso acontece porque, ao finalizar o modelo, estamos treinando-o com todos os dados disponíveis, e não apenas com uma parte dos dados. Dessa forma, o modelo finalizado é mais ajustado aos dados de treinamento e, portanto, pode apresentar melhor desempenho na previsão.</p>
#
# <p align="justify">No entanto, é importante ressaltar que, ao testar o modelo finalizado com o conjunto de dados de teste original, estamos usando dados que o modelo já viu antes, o que pode causar over-fitting e superestimar a capacidade de generalização do modelo. Para avaliar adequadamente a capacidade de generalização do modelo, é importante usar dados não vistos pelo modelo durante o treinamento e a validação.</p>
#
# <p align="justify">Após finalizado, podemos dar print no objeto do modelo para verificar os parâmetros utilizados para os melhores resultados.</p>

# %%
# Importar a função pprint para imprimir dicionários e outras estruturas de forma legível e formatada
from pprint import pprint

# Impressão dos Hiperparâmetros 
pprint(final_gbr.named_steps['actual_estimator'].get_params())
# Out:
# {'alpha': 0.9,
#  'ccp_alpha': 0.0,
#  'criterion': 'friedman_mse',
#  'init': None,
#  'learning_rate': 0.1,
#  'loss': 'squared_error',
#  'max_depth': 3,
#  'max_features': None,
#  'max_leaf_nodes': None,
#  'min_impurity_decrease': 0.0,
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'min_weight_fraction_leaf': 0.0,
#  'n_estimators': 100,
#  'n_iter_no_change': None,
#  'random_state': 1,
#  'subsample': 1.0,
#  'tol': 0.0001,
#  'validation_fraction': 0.1,
#  'verbose': 0,
#  'warm_start': False}

# %% [markdown]
# ### **6.5 Prevendo em Dados Novos**
#
# <p align="justify">A função predict_model( ) é uma função do PyCaret que permite fazer previsões em dados novos usando o modelo treinado. Para isso, basta passar os dados novos (ou seja, os dados que não foram usados para treinar o modelo) como argumento para o parâmetro data.</p>
#
# <p align="justify">Essa é uma etapa importante no processo de desenvolvimento do modelo, pois é essencial verificar se o modelo é capaz de fazer previsões precisas em dados que ele nunca viu antes.</p>
#
# <p align="justify">No contexto do projeto, a porção de dados que nunca foi vista pelo modelo corresponde a 10% do conjunto de dados original e foi separada anteriormente. Esses dados são usados para simular novos dados reais que o modelo encontraria em produção.</p>
#
# <p align="justify">A função predict_model( ) usa o modelo treinado para fazer previsões nesses dados novos e retorna uma tabela com as previsões e as probabilidades de cada classe (no caso de classificação) ou os valores previstos (no caso de regressão). Essa tabela pode ser usada para avaliar o desempenho do modelo em dados novos e identificar possíveis problemas de generalização.</p>

# %%
# Previsão em dados não vistos
unseen_predictions = predict_model(final_gbr, data=test, round=2)
unseen_predictions.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_e08d7" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e08d7_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_e08d7_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_e08d7_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_e08d7_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_e08d7_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_e08d7_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_e08d7_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e08d7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e08d7_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_e08d7_row0_col1" class="data row0 col1" >2453.75</td>
# ...

# %% [markdown]
# ### **6.6 Salvando o Modelo**
#
# <p align="justify">Após finalizarmos nosso trabalho com o modelo, é necessário mantê-lo utilizável e disponível para realizar novas previsões em novos dados.</p>
#
# <p align="justify">A função "save_model( )" do PyCaret, permite salvarmos um modelo treinado em um arquivo específico. Ela pode ser usada para salvar o modelo em um formato que pode ser carregado posteriormente para fazer previsões em novos dados sem a necessidade de treinarmos novamente o modelo.</p>
#
# <p align="justify">A função save_model( ) recebe dois argumentos: o modelo treinado e o nome do arquivo onde o modelo será salvo. Por exemplo, para salvar o modelo treinado final_gbr em um arquivo chamado gbr_model, podemos usar o seguinte código:

# %%
# Salvando o modelo
save_model(final_gbr,'Modelo_Final_28_04_23')
# Out:
# Transformation Pipeline and Model Successfully Saved
# (Pipeline(memory=FastMemory(location=/tmp/joblib),
#           steps=[('numerical_imputer',
#                   TransformerWrapper(include=['age', 'bmi', 'children'],
#                                      transformer=SimpleImputer())),
#                  ('categorical_imputer',
#                   TransformerWrapper(include=['sex', 'smoker', 'region'],
#                                      transformer=SimpleImputer(strategy='most_frequent'))),
#                  ('ordinal_encoding',
#                   TransformerWrapper(include=['sex', 'smoker...
#                                                                           'data_type': dtype('O'),
#                                                                           'mapping': female    0
#  male      1
#  NaN      -1
#  dtype: int64},
#                                                                          {'col': 'smoker',
# ...

# %% [markdown]
# ### **6.7 Carregando um Modelo Salvo**
#
# <p align="justify">Para carregarmos um modelo salvo para uso em dados novos, basta usarmos a função "load_model( )" e então aplicarmos o modelo salvo em novos dados para uma nova previsão, conforme código abaixo:</p>

# %%
# Carregando um modelo salvo
saved_final_gbr = load_model('Modelo_Final_28_04_23')
# Out:
# Transformation Pipeline and Model Successfully Loaded

# %% [markdown]
# <p align="justify">Uma vez carregado, podemos simplesmente usá-lo em um novo conjunto de dados utilizando a função "predict_model( )". Os passos possíveis são os mesmo que apresentados anteriormente, desde o treino do modelo.</p>

# %%
# Fazendo previsões com o modelo salvo
new_prediction = predict_model(saved_final_gbr, data=test)
new_prediction.head()
# Out:
# <style type="text/css">
# </style>
# <table id="T_4ec16" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4ec16_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_4ec16_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_4ec16_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_4ec16_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_4ec16_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_4ec16_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_4ec16_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4ec16_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4ec16_row0_col0" class="data row0 col0" >Gradient Boosting Regressor</td>
#       <td id="T_4ec16_row0_col1" class="data row0 col1" >2453.7469</td>
# ...

# %% [markdown]
# ## **7. Desafios na gestão de risco e precificação de seguros de saúde**
#
# <p align="justify">Existem vários problemas de negócio associados à previsão de custo de seguro saúde, alguns dos quais incluem:
#
# * <p align="justify">Precificação do seguro: Uma questão chave para as seguradoras de saúde é a precificação do seguro. O objetivo é estabelecer preços que sejam atraentes para os clientes e, ao mesmo tempo, gerar lucros para a empresa. A previsão de custo de seguro de saúde pode ajudar as seguradoras a definir preços competitivos e equilibrados para seus serviços.</p>
#
# * <p align="justify">Gerenciamento de risco: Outro problema de negócio é o gerenciamento de risco. As seguradoras precisam avaliar cuidadosamente o risco de cada cliente para determinar o prêmio a ser cobrado. A previsão de custo de seguro de saúde pode ajudar as seguradoras a entender o risco de cada cliente e, assim, definir prêmios apropriados.</p>
#
# * <p align="justify">Gerenciamento de sinistros: As seguradoras também precisam gerenciar sinistros de forma eficiente. A previsão de custo de seguro de saúde pode ajudar a identificar clientes com maior probabilidade de apresentar sinistros, permitindo que as seguradoras se preparem melhor para gerenciar esses sinistros e, assim, reduzir os custos associados.</p>
#
# * <p align="justify">Desenvolvimento de produtos: As seguradoras de saúde também precisam desenvolver produtos que atendam às necessidades dos clientes. A previsão de custo de seguro de saúde pode ajudar a identificar os recursos e benefícios mais valorizados pelos clientes, permitindo que as seguradoras desenvolvam produtos que sejam mais atraentes e competitivos.</p>
#
# ### **7.1 Aplicações de Machine Learning (AutoML) na gestão de seguros de saúde**
#
# <p align="justify">Em resumo, o modelo de regressão treinado e analisado com o algorítmo Gradient Boosting Regressor (GBR) pode ser usado para ajudar as seguradoras de saúde a lidar com vários problemas de negócio, incluindo a precificação do seguro, o gerenciamento de risco, o gerenciamento de sinistros e o desenvolvimento de produtos. No entanto, é importante lembrar que o modelo é uma ferramenta, e a aplicação bem-sucedida do modelo em problemas de negócio depende de vários fatores, como a qualidade dos dados, a precisão do modelo e a habilidade dos usuários em interpretar e aplicar os resultados. Abaixo, vamos demonstrar  algumas soluções que o modelo (GBR) pode ajudar:</p></p>
#
# * <p align="justify">Precificação do seguro: O modelo GBR pode ser usado para prever o custo do seguro de saúde para novos clientes com base em seus atributos, permitindo que as seguradoras definam preços competitivos e equilibrados para seus serviços.</p>
#
# * <p align="justify">Gerenciamento de risco: O modelo GBR pode ser usado para identificar os fatores que têm maior impacto no custo do seguro de saúde, permitindo que as seguradoras avaliem cuidadosamente o risco de cada cliente e definam prêmios apropriados.</p>
#
# * <p align="justify">Gerenciamento de sinistros: O modelo GBR pode ser usado para identificar clientes com maior probabilidade de apresentar sinistros e, assim, permitir que as seguradoras se preparem melhor para gerenciar esses sinistros e reduzir os custos associados.</p>
#
# * <p align="justify">Desenvolvimento de produtos: O modelo GBR pode ajudar as seguradoras a identificar os recursos e benefícios mais valorizados pelos clientes, permitindo que desenvolvam produtos que atendam melhor às necessidades dos clientes.</p>

# %% [markdown]
# ## **8. Conclusão**
#
# <p align="justify">Com base no modelo de regressão desenvolvido para prever o custo do seguro saúde, podemos tirar as seguintes conclusoes:</p>
#
# ><p align="justify">Dos 19 diferentes modelos de Regressão gerados pelo pacote PyCaret, o modelo Gradient Boosting Regressor (GBR) se destacou entre os demais, apresentando as melhores médias das métricas de desempenho (MAE, MSE, RMSE, R2, RMSLE e MAPE) para prever o custo do seguro saúde.</p>
#
# ><p align="justify">O modelo original foi melhor do que o modelo ajustado, pois a busca em grade não encontrou nenhuma combinação de hiperparâmetros que melhorasse significativamente o desempenho do modelo em relação ao original Portanto, o modelo que se apresenta melhor, considerando as métricas de desempenho médio, é o modelo original, ou seja, o Gradient Boosting Regressor sem ajuste de hiperparâmetros.</p>
#
# ><p align="justify">O estudo revelou que as principais características que influenciam o custo do seguro de saúde são a idade, o IMC e o fumante. Isso sugere que essas características devem ser levadas em consideração ao fazer previsões de custo de seguro saúde.</p>
#
# ><p align="justify">A análise de correlação, também confirmou que o custo do seguro de saúde está mais fortemente correlacionado com a idade, o IMC e o fumo.</p>
#
# ><p align="justify">O modelo desenvolvido poder ser usado para prever o custo de seguro de saúde para novos dados.</p>

# %% [markdown]
# ## **9. Referência Bibliográfica**
#
# AGÊNCIA NACIONAL DE SAÚDE COMPLEMENTAR. Seguro Saúde. Disponível em: https://www.gov.br/ans/pt-br [ Links ]
#
# MINISTÉRIO DA SAÚDE. Plano Nacional de Saúde 2020/2023. Disponível em: https://bvsms.saude.gov.br/bvs/publicacoes/plano_nacional_saude_2020_2023.pdf [ Links ]
#
# WORLD HEALTH ORGANIZATION. The implications of artificial intelligence and machine learning in health financing for achieving universal health coverage - Findings from a rapid literature review. Disponível em: https://www.who.int/publications/i/item/9789240064010 [ Links ]
